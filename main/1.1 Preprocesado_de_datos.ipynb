# %% [markdown]
# # Preprocesamiento de datos sobre desastres naturales en los años 2016-2017-2018

# %% [markdown]
#  Fuente: https://public.emdat.be/

# %% [markdown]
# **1. Importamos la base de datos**

# %%
import pandas as pd

df = pd.read_excel('/content/drive/MyDrive/Colab Notebooks/database_2010_2024.xlsx')

df.head()
# Out:
#           DisNo. Historic Classification Key Disaster Group Disaster Subgroup  \
# 0  2009-0595-IND       No    nat-met-ext-col        Natural    Meteorological
# 1  2010-0002-TJK       No    nat-geo-ear-gro        Natural       Geophysical
# 2  2010-0003-SLB       No    nat-geo-ear-gro        Natural       Geophysical
# 3  2010-0004-BGD       No    tec-tra-roa-roa  Technological         Transport
# 4  2010-0005-IND       No    tec-tra-rai-rai  Technological         Transport
#
#          Disaster Type Disaster Subtype          External IDs Event Name  ISO  \
# 0  Extreme temperature        Cold wave  GLIDE:CW-2010-000013        NaN  IND
# 1           Earthquake  Ground movement  GLIDE:EQ-2010-000001        NaN  TJK
# 2           Earthquake  Ground movement       USGS:usp000h5np        NaN  SLB
# 3                 Road             Road                   NaN        NaN  BGD
# 4                 Rail             Rail                   NaN        NaN  IND
#
#    ... Reconstruction Costs ('000 US$)  \
# 0  ...                             NaN
# 1  ...                             NaN
# 2  ...                             NaN
# 3  ...                             NaN
# 4  ...                             NaN
#
#   Reconstruction Costs, Adjusted ('000 US$) Insured Damage ('000 US$)  \
# 0                                       NaN                       NaN
# 1                                       NaN                       NaN
# 2                                       NaN                       NaN
# 3                                       NaN                       NaN
# 4                                       NaN                       NaN
#
#   Insured Damage, Adjusted ('000 US$) Total Damage ('000 US$)  \
# 0                                 NaN                     NaN
# 1                                 NaN                  1500.0
# 2                                 NaN                     NaN
# 3                                 NaN                     NaN
# 4                                 NaN                     NaN
#
#   Total Damage, Adjusted ('000 US$)        CPI  \
# 0                               NaN  71.563596
# 1                            2096.0  71.563596
# 2                               NaN  71.563596
# 3                               NaN  71.563596
# 4                               NaN  71.563596
#
#                                          Admin Units  Entry Date  Last Update
# 0  [{"adm1_code":1489,"adm1_name":"Delhi"},{"adm1...  2010-08-04   2023-09-25
# 1      [{"adm2_code":37581,"adm2_name":"Vanchskiy"}]  2010-02-03   2023-09-25
# 2  [{"adm2_code":25652,"adm2_name":"Administrativ...  2014-05-12   2023-09-25
# 3                                                NaN  2010-01-05   2023-09-25
# 4                                                NaN  2010-01-05   2023-09-25
#
# [5 rows x 46 columns]

# %% [markdown]
# **2. Apartamos las columnas que necesitamos.**

# %%
# Mantener solo las variables mencionadas a continuacion.

columns_to_keep = ['Start Year', 'Start Month', 'Start Day',
    'Country', 'Region', 'Location', 'Magnitude',
    "Disaster Subgroup", 'Total Damage (\'000 US$)', 'Total Deaths' ]
df = df[columns_to_keep]

# Mostramos los primeros 5 elementos para identificar que se realizo el primer Filtro
df.head()
# Out:
#    Start Year  Start Month  Start Day          Country   Region  \
# 0        2010          1.0        2.0            India     Asia
# 1        2010          1.0        2.0       Tajikistan     Asia
# 2        2010          1.0        3.0  Solomon Islands  Oceania
# 3        2010          1.0        1.0       Bangladesh     Asia
# 4        2010          1.0        2.0            India     Asia
#
#                                             Location  Magnitude  \
# 0  Srinagar city ('72808' district, '40424' Jammu...       -9.0
# 1  Uskrogh, Rogh, Payshanbeobod, Gishkhun, Dashti...        5.4
# 2                  Administrative unit not available        7.1
# 3                                      Kanaipur road        NaN
# 4                                                NaN        NaN
#
#   Disaster Subgroup  Total Damage ('000 US$)  Total Deaths
# 0    Meteorological                      NaN         100.0
# 1       Geophysical                   1500.0           NaN
# 2       Geophysical                      NaN           NaN
# 3         Transport                      NaN          17.0
# 4         Transport                      NaN          10.0

# %% [markdown]
# **3. Filtramos los desastres hidrologicos**

# %%
df = df[df["Disaster Subgroup"] == "Hydrological"]

df.head()
# Out:
#     Start Year  Start Month  Start Day      Country  Region  \
# 6         2010          1.0        NaN      Burundi  Africa
# 8         2010          1.0        4.0     Pakistan    Asia
# 15        2010          1.0       14.0  Philippines    Asia
# 16        2010          1.0       18.0        Egypt  Africa
# 17        2010          1.0       19.0       Israel    Asia
#
#                                              Location  Magnitude  \
# 6   Gatumba village (Mutimbuzi district, Bujumbura...        NaN
# 8   Administrative unit not available district (Ja...        NaN
# 15  Jabonga, Las Nieves, Santiago areas (Agusan de...        NaN
# 16  El Arish 1 district (North Sinai province), Ra...   226100.0
# 17                         Southern District province        NaN
#
#    Disaster Subgroup  Total Damage ('000 US$)  Total Deaths
# 6       Hydrological                      NaN           NaN
# 8       Hydrological                  18000.0          19.0
# 15      Hydrological                     22.0           2.0
# 16      Hydrological                      NaN          12.0
# 17      Hydrological                      NaN           2.0

# %% [markdown]
# **4. Hacemos limpieza de los datos nulos eliminando las filas que contengan datos NaN en este caso en la columna magnitud.**

# %%
df = df.dropna(subset=['Magnitude'])

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 506 entries, 16 to 7898
# Data columns (total 10 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Start Year               506 non-null    int64
#  1   Start Month              506 non-null    float64
#  2   Start Day                496 non-null    float64
#  3   Country                  506 non-null    object
#  4   Region                   506 non-null    object
#  5   Location                 504 non-null    object
#  6   Magnitude                506 non-null    float64
#  7   Disaster Subgroup        506 non-null    object
#  8   Total Damage ('000 US$)  196 non-null    float64
#  9   Total Deaths             410 non-null    float64
# dtypes: float64(5), int64(1), object(4)
# memory usage: 43.5+ KB

# %% [markdown]
# **5. Con la siguiente funcion determinamos la limpieza que se realizo.**

# %%
df.isnull().sum()
# Out:
# Start Year                   0
# Start Month                  0
# Start Day                   10
# Country                      0
# Region                       0
# Location                     2
# Magnitude                    0
# Disaster Subgroup            0
# Total Damage ('000 US$)    310
# Total Deaths                96
# dtype: int64

# %% [markdown]
# **6. Para finalizar ajustamos el indice de manera organizada para tener coherencia en la data.**

# %%
indices = list(range(1,507))
df.index = indices
df.head()
# Out:
#    Start Year  Start Month  Start Day                           Country  \
# 1        2010          1.0       18.0                             Egypt
# 2        2010          1.0        1.0  Bolivia (Plurinational State of)
# 3        2010          1.0       11.0                            Panama
# 4        2010          1.0       26.0                            Mexico
# 5        2010          2.0       10.0                              Peru
#
#      Region                                           Location  Magnitude  \
# 1    Africa  El Arish 1 district (North Sinai province), Ra...   226100.0
# 2  Americas  Beni, Chuquisaca, Cochabamba, La Paz and Santa...   102200.0
# 3  Americas  Bocas del Toro, Chiriqui, Vergaguas, Colon pro...    23340.0
# 4  Americas  Distrito Federal, Mexico city, Michoacan provi...   122621.0
# 5  Americas  La Esperanza, El Porvenir, Salaverry towns (Tr...   305800.0
#
#   Disaster Subgroup  Total Damage ('000 US$)  Total Deaths
# 1      Hydrological                      NaN          12.0
# 2      Hydrological                      NaN          26.0
# 3      Hydrological                      NaN           NaN
# 4      Hydrological                  16000.0          41.0
# 5      Hydrological                      NaN          20.0

# %% [markdown]
# **7.Guardamos el archivo de la data**

# %%
df.to_excel("/content/drive/MyDrive/Colab Notebooks/database_procesada_2010_2024.xlsx")
